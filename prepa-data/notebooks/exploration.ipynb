# %%
import pandas as pd
from sqlalchemy import create_engine
engine = create_engine('postgresql+psycopg2://postgres:postgres@localhost:5432/analytics_db')
student_metrics = pd.read_sql('SELECT * FROM student_metrics LIMIT 50', engine)
student_metrics.head()
